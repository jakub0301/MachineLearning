# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#My Twitter API Authentication Variables
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('Donald Trump', count=200)

data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(30))


print(tweets[0].created_at)
# Out:
#                                                Tweets
# 0   RT @MollyMcKew: Bill Barr has become the Jeff ...
# 1   RT @threadreaderapp: @BaddCompani Hallo there ...
# 2   RT @middleageriot: BREAKING: Republicans give ...
# 3   It's always amazed me how much praise is heape...
# 4   TRUMP ENABLERS ARE LYING ABOUT “PROCESS” … Con...
# 5   RT @AishaStaggers: As a former employee of Ben...
# 6   RT @dbongino: This partisan hack was a KEY pla...
# 7   RT @JoeBiden: Donald Trump lacks the moral aut...
# 8   RT @RonWyden: NEWS: I’m launching an investiga...
# 9   RT @gregolear: Let’s talk about Donald Trump a...
# 10  RT @grantstern: Rudy Giuliani's brilliant butt...
# 11  RT @MotherJones: Donald Trump's biggest enemy ...
# 12  RT @thestate: At least 10 Benedict College stu...
# 13  RT @ProudResister: BREAKING: We have just ente...
# 14  RT @MarkSimoneNY: Adam Schiff says President D...
# 15  Kanye publicly supports Donald Trump, a known ...
# 16  RT @conservmillen: Kanye West just released a ...
# 17  I’m sure the POS wasn’t welcome and was told s...
# 18  @cvptexas @JohnCornyn No. Actually Donald J Tr...
# 19  RT @RichieFed: The Trump Organization is consi...
# 20  RT @JohnBWellsCTM: Hillary Clinton compares Do...
# 21  RT @GregNorberg: Here is the video of Donald J...
# 22  RT @ProudResister: BREAKING: We have just ente...
# 23  RT @PeeksKyra: “wHaT has hE dOne foR the BlAcK...
# 24  RT @THeinrich22: Hey America, have ya met Mann...
# 25  RT @briantylercohen: Trump on Ambassador Bill ...
# 26  RT @willchamberlain: I think the decision to a...
# 27  RT @willchamberlain: I think the decision to a...
# 28  RT @willchamberlain: I think the decision to a...
# 29  Boris Johnson Britans very own Donald trump. #...
# 2019-10-25 19:55:29

# %%
import nltk
nltk.download('vader_lexicon')

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @MollyMcKew: Bill Barr has become the Jeff ...
# 1   RT @threadreaderapp: @BaddCompani Hallo there ...
# 2   RT @middleageriot: BREAKING: Republicans give ...
# 3   It's always amazed me how much praise is heape...
# 4   TRUMP ENABLERS ARE LYING ABOUT “PROCESS” … Con...
# ..                                                ...
# 95  RT @realDonaldTrump: “Donald J. Trump is an ab...
# 96  RT @realDonaldTrump: “Donald J. Trump is an ab...
# 97  RT @KamalaHarris: Donald Trump has shown us he...
# 98  RT @tonyschwartz: I wish George Conway would g...
# 99  RT @LisaMei62: HA! @seanhannity just finished ...
#
#                                              polarity
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3   {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'comp...
# 4   {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'comp...
# ..                                                ...
# 95  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 96  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 97  {'neg': 0.072, 'neu': 0.928, 'pos': 0.0, 'comp...
# 98  {'neg': 0.0, 'neu': 0.886, 'pos': 0.114, 'comp...
# 99  {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compou...
#
# [100 rows x 2 columns]
